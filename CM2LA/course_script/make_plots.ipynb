# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
td_data = np.load('td_loss_hist.npz')

# %%
orth_data = np.load('orth_loss_hist.npz')

# %%
classic_data = np.load('classic_loss_hist.npz')

# %%
td_data
# Out:
# NpzFile 'td_loss_hist.npz' with keys: labels, arr_0, arr_1, arr_2, arr_3

# %%
plt.figure(figsize = (12,4))
plt.semilogy(orth_data['arr_1'], linewidth = 2, label = 'orth')
plt.semilogy(td_data['arr_1'], linewidth =2, label = 'orth_td')
plt.semilogy(classic_data['arr_1'], label = 'classic')
plt.xlabel('the number of iterations')
plt.ylabel('training loss')
plt.title("MSE Training Loss Trajectory - 3 Architectures (Trunk Only)")
plt.tight_layout()
# plt.suptitle(title_str + '\n')
plt.legend()
plt.savefig("deeponet_2step_training.png")
plt.show()
